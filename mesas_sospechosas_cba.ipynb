# %% [markdown]
# # Relevamiento de carga de datos sospechosa en las elecciones de Provincia de Córdoba
#
# Este análisis es mi aporte para hacer el trabajo de **chequeo manual de telegramas de las PASO 2017** en Córdoba detectando aquellas resultados estádisticamente raras (no quiere decir que todas las mesas listadas estén incorrectas).
#
# Para esto realizé un programa que obtiene los datos digitalizados de cada una de las mesas y los estructuré en una base de datos para hacer agregaciones y consultas.
#
# Por ejemplo, basado en la idea de que los resultados en una mesa son similares en un circuito, se pueden detectar aquellas mesas que tienen resultados muy distintos.
#
# Las tablas resultantes muestran algunos datos e incluyen el link para ver el telegrama en el sitio oficial para que revisemos entre tod@s.
#
# Todo el [código fuente está disponible en github](http://github.com/mgaitan/mesas_ba/)
#
# **Gracias por difundir**
#
# - Martín Gaitán [`@tin_nqn_`](https://twitter.com/tin_nqn_)
#
#
#
# <div class="alert alert-info" role="alert">Si querés podés <a href="#resultados">ir a los resultados</a>
#
#
#
#
# </div>

# %% [markdown]
# ### Generación de base de datos
#
# Utilizo el ORM de Django para modelar la base de datos y luego importo los CSVs del [crawler del escrutinio provisorio](https://github.com/mgaitan/mesas_ba/tree/master/mesas_ba), mesa por mesa.

# %%
# %load_ext django_orm_magic

# %%
# %%django_orm
# from django.db import models
# from django.db.models import Sum
#
# class Seccion(models.Model):
#     numero = models.CharField(max_length=10)
#     nombre = models.CharField(max_length=100)
#
#     def __str__(self):
#         return f'{self.numero} - {self.nombre}'
#
# class Circuito(models.Model):
#     numero = models.CharField(max_length=10)
#     seccion = models.ForeignKey('Seccion')
#
#     def __str__(self):
#         return u"Circuito %s (%s)" % (self.numero, self.seccion)
#
# class Mesa(models.Model):
#     numero = models.CharField(max_length=10)
#     circuito = models.ForeignKey('Circuito')
#     fake_id = models.CharField(max_length=100, unique=True)
#     url = models.CharField(max_length=200)
#
#     class Meta:
#         unique_together = ('circuito', 'numero')
#
#     @property
#     def computados(self):
#         return self.resultados.aggregate(Sum('votos'))['votos__sum']
#
#     def __str__(self):
#         return u"Mesa %s (%s)" % (self.numero, self.circuito)
#
#     @property
#     def absolute_url(self):
#         return f'http://www.resultados.gob.ar/99/resu/content/telegramas/{self.url}'
#
#
# class Partido(models.Model):
#     nombre = models.CharField(max_length=100, unique=True)
#
#     def __str__(self):
#         return self.nombre
#
#
# class Opcion(models.Model):
#     nombre = models.CharField(max_length=100, unique=True)
#     partido = models.ForeignKey('Partido', null=True)    # blanco / nulo / etc.
#
#     def __str__(self):
#         return self.nombre
#
# class VotoMesa(models.Model):
#     mesa = models.ForeignKey('Mesa', related_name='resultados')
#     categoria = models.CharField(max_length=20, choices=(('dip', 'Diputados'), ('sen', 'Senadores')))
#     opcion = models.ForeignKey('Opcion')
#     votos = models.IntegerField()
#
#     def __str__(self):
#         return u"%s: %s -> %d" % (self.get_categoria_display(), self.opcion, self.votos)
#
#
#     class Meta:
#         unique_together = ('mesa', 'opcion', 'categoria')

# %% [markdown]
# ## Importación de datos a los modelos

# %%
from csv import DictReader

# %%
Seccion.objects.all()
# Out:
# <QuerySet []>

# %% [markdown]
# Importo secciones, circuitos y mesas de los distintos archivos

# %%
for seccion in DictReader(open('secciones.csv')):
    Seccion.objects.create(**seccion)

# %%
secciones = {s.numero: s for s in Seccion.objects.all()}
circuitos = []
for circuito in DictReader(open('circuitos.csv')):
    circuito['seccion'] = secciones[circuito['seccion']] 
    circuitos.append(Circuito(**circuito))
Circuito.objects.bulk_create(circuitos);

# %%
circuitos = {c.numero: c for c in Circuito.objects.all()}
mesas = []
for mesa in DictReader(open('mesas.csv')):
    mesa['circuito'] = circuitos[mesa['circuito']]
    mesas.append(Mesa(**mesa))
Mesa.objects.bulk_create(mesas);

# %% [markdown]
# El archivo `resultados.csv` pesa casi 100mb y tiene una fila por cada mesa-opcion, para senadores y diputados.
# Para cargarlo más rapido (sino puede tardar muchisimo) hice unas pequeñas optimizaciones.
#
# - Importo partidos y listas que existan primero y armo un diccionario para no tener que hacer consultas luego
# - Hago "chunks" e inserto varias filas de resultados a la vez.
#
# Con esto tarda unos 5' en cargar.

# %%
from itertools import zip_longest

def grouper(n, iterable, fillvalue=None):
    args = [iter(iterable)] * n
    return zip_longest(fillvalue=fillvalue, *args)

# %%
import pandas as pd
partidos_listas = pd.read_csv('resultados.csv', usecols=['partido','lista'])
partidos_listas.drop_duplicates(inplace=True)

# %%
partidos_listas.fillna('', inplace=True)
partidos_listas
# Out:
#                              lista                                     partido
# 0                                                                        nulos
# 1                                                                      blancos
# 2                                                                   recurridos
# 3                                                                   impugnados
# 4                          NARANJA                                   HUMANISTA
# 5                        MARGARITA                                         GEN
# 6                   CORDOBA CAMBIA                            PRIMERO LA GENTE
# 7                VALORES EN ACCION                   ENCUENTRO VECINAL CORDOBA
# 8                       NUEVO PAIS  POLITICA ABIERTA PARA LA INTEGRIDAD SOCIAL
# 9                POR UN NUEVO PAIS  POLITICA ABIERTA PARA LA INTEGRIDAD SOCIAL
# 10               POR UN PAIS MEJOR  POLITICA ABIERTA PARA LA INTEGRIDAD SOCIAL
# 11                 JUNTOS POR PAIS  POLITICA ABIERTA PARA LA INTEGRIDAD SOCIAL
# 12                            ROJA   FRENTE DE IZQUIERDA Y DE LOS TRABAJADORES
# 13                      COMPROMISO                                       SOMOS
# 14  MOVIMIENTO DE UNIDAD PERONISTA                           UNION POR CORDOBA
# 15                          UNIDAD                    FRENTE CORDOBA CIUDADANA
# 16         UNIDAD DE LA  IZQUIERDA       IZQUIERDA AL FRENTE POR EL SOCIALISMO
# 17                CAMBIANDO JUNTOS                                   CAMBIEMOS
# 18       PARA LA DEMOCRACIA SOCIAL                                   CAMBIEMOS

# %%
for _, row in partidos_listas.iterrows():
    if not row.lista:
        Opcion.objects.create(nombre=row.partido)
    else:
        partido, _ = Partido.objects.get_or_create(nombre=row.partido)
        Opcion.objects.create(nombre=row.lista, partido=partido)

# %%
opciones = {o.nombre: o for o in Opcion.objects.all()}
opciones
# Out:
# {'CAMBIANDO JUNTOS': <Opcion: CAMBIANDO JUNTOS>,
#  'COMPROMISO': <Opcion: COMPROMISO>,
#  'CORDOBA CAMBIA': <Opcion: CORDOBA CAMBIA>,
#  'JUNTOS POR PAIS': <Opcion: JUNTOS POR PAIS>,
#  'MARGARITA': <Opcion: MARGARITA>,
#  'MOVIMIENTO DE UNIDAD PERONISTA': <Opcion: MOVIMIENTO DE UNIDAD PERONISTA>,
#  'NARANJA': <Opcion: NARANJA>,
#  'NUEVO PAIS': <Opcion: NUEVO PAIS>,
#  'PARA LA DEMOCRACIA SOCIAL': <Opcion: PARA LA DEMOCRACIA SOCIAL>,
#  'POR UN NUEVO PAIS': <Opcion: POR UN NUEVO PAIS>,
#  'POR UN PAIS MEJOR': <Opcion: POR UN PAIS MEJOR>,
#  'ROJA': <Opcion: ROJA>,
#  'UNIDAD': <Opcion: UNIDAD>,
#  'UNIDAD DE LA  IZQUIERDA': <Opcion: UNIDAD DE LA  IZQUIERDA>,
#  'VALORES EN ACCION': <Opcion: VALORES EN ACCION>,
#  'blancos': <Opcion: blancos>,
#  'impugnados': <Opcion: impugnados>,
#  'nulos': <Opcion: nulos>,
#  'recurridos': <Opcion: recurridos>}

# %%
mesas = {m.fake_id: m for m in Mesa.objects.all()}
VotoMesa.objects.all().delete()
# Out:
# (45528, {'orm_magic.VotoMesa': 45528})

# %%
for chunk in grouper(300, DictReader(open('resultados.csv'))):
    resultados = []
    for resultado in chunk:
        if not resultado:
            continue
        mesa = mesas[resultado['mesa']]
        lista = resultado['lista'] or resultado['partido']
        opcion = opciones[lista]
        try:
            votos = int(resultado['votos'] or 0)
        except ValueError:
            print('**votos no validos', resultado)
            continue
        
        resultados.append(VotoMesa(mesa=mesa, 
                               opcion=opcion, 
                               votos=votos, 
                               categoria=resultado['categoria']))
    VotoMesa.objects.bulk_create(resultados)

# %% [markdown]
# <div id="resultados"></div>
#
# ## RESULTADOS
#
#
#
# Teniendo la base de datos puedo hacer cualquier tipo de consulta, por mesa, por circuito, totales, etc.
#
# Primero calculemos los porcentajes totales para diputados y senadores

# %%
for o in Opcion.objects.all():
    print(o.id, o.nombre, o.partido)
# Out:
# 1 nulos None
# 2 blancos None
# 3 recurridos None
# 4 impugnados None
# 5 NARANJA HUMANISTA
# 6 MARGARITA GEN
# 7 CORDOBA CAMBIA PRIMERO LA GENTE
# 8 VALORES EN ACCION ENCUENTRO VECINAL CORDOBA
# 9 NUEVO PAIS POLITICA ABIERTA PARA LA INTEGRIDAD SOCIAL
# 10 POR UN NUEVO PAIS POLITICA ABIERTA PARA LA INTEGRIDAD SOCIAL
# 11 POR UN PAIS MEJOR POLITICA ABIERTA PARA LA INTEGRIDAD SOCIAL
# 12 JUNTOS POR PAIS POLITICA ABIERTA PARA LA INTEGRIDAD SOCIAL
# 13 ROJA FRENTE DE IZQUIERDA Y DE LOS TRABAJADORES
# 14 COMPROMISO SOMOS
# 15 MOVIMIENTO DE UNIDAD PERONISTA UNION POR CORDOBA
# 16 UNIDAD FRENTE CORDOBA CIUDADANA
# 17 UNIDAD DE LA  IZQUIERDA IZQUIERDA AL FRENTE POR EL SOCIALISMO
# 18 CAMBIANDO JUNTOS CAMBIEMOS
# 19 PARA LA DEMOCRACIA SOCIAL CAMBIEMOS

# %%
UPC = [15]
CAMBIEMOS = [18, 19]
FCC = [16]
FIT = [13]
TODOS = {'UPC': UPC, 'CAMBIEMOS': CAMBIEMOS, 'FCC': FCC, 'FIT': FIT}

# %%
total_positivos = VotoMesa.objects.filter(opcion__partido__isnull=False).aggregate(v=Sum('votos'))['v']
total_positivos
# Out:
# 1874318

# %%
from django.db.models import Avg, Sum

# %%
results = {}
for part, ids in TODOS.items():
    vot = VotoMesa.objects.filter(opcion__id__in=ids).aggregate(v=Sum('votos'))['v']
    results[part] =  vot, vot/total_positivos

# %%
results
# Out:
# {'CAMBIEMOS': (850778, 0.45391337008981403),
#  'FCC': (189087, 0.10088309454425556),
#  'FIT': (82584, 0.044060826391252715),
#  'UPC': (546197, 0.2914110625838305)}

# %% [markdown]
# ### Mesas donde el FCC sacó menos del 30% de los votos promedio en su circuito

# %%
from IPython.display import display_html, HTML

# %%
mesas = []
for circuito in Circuito.objects.all():
    promedio_circuito = VotoMesa.objects.filter(mesa__circuito=circuito, opcion__id__in=FCC).aggregate(p=Avg('votos'))['p']
    if not promedio_circuito:
        continue
    
    for mesa in Mesa.objects.filter(circuito=circuito, resultados__votos__gt=0, 
                                    resultados__votos__lte=int(promedio_circuito * .3), 
                                    resultados__opcion__id__in=FCC):
        vot = mesa.resultados.get(opcion__id__in=FCC).votos
        mesas.append((mesa, vot, promedio_circuito))

# %%
len(mesas)
# Out:
# 34

# %%
html = '<table class="table"><tr><th>Mesa</th><th>Circuito</th><th>Computados</th><th>Votos FCC</th><th>Promedio FCC/Circ</th></tr>'
for l in mesas:
    mesa, vot, promedio_circuito = l
    html += f"<tr><td><a href='{mesa.absolute_url}'>Mesa {mesa.numero}</a></td><td> {mesa.circuito} </td><td> {mesa.computados} </td><td>{vot}</td><td> {promedio_circuito:.2f}</td></tr>"
html += '</table>'
    
display_html(HTML(html))
# Out:
# <table class="table"><tr><th>Mesa</th><th>Circuito</th><th>Computados</th><th>Votos FCC</th><th>Promedio FCC/Circ</th></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/009/0126/040090126_04998.htm'>Mesa 04998</a></td><td> Circuito 0126 (009 - Marcos Juárez) </td><td> 238 </td><td>3</td><td> 11.11</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/009/0133/040090133_05103.htm'>Mesa 05103</a></td><td> Circuito 0133 (009 - Marcos Juárez) </td><td> 219 </td><td>4</td><td> 18.76</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/012/0156/040120156_05520.htm'>Mesa 05520</a></td><td> Circuito 0156 (012 - Punilla) </td><td> 189 </td><td>4</td><td> 22.79</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/005/0060/040050060_04246.htm'>Mesa 04246</a></td><td> Circuito 0060 (005 - General Roca) </td><td> 237 </td><td>3</td><td> 17.60</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/004/0044/040040044_04100.htm'>Mesa 04100</a></td><td> Circuito 0044 (004 - Cruz del Eje) </td><td> 194 </td><td>3</td><td> 29.52</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/014/0213/040140213_06413.htm'>Mesa 06413</a></td><td> Circuito 0213 (014 - Río Primero) </td><td> 198 </td><td>1</td><td> 3.75</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0028/040030028_03434.htm'>Mesa 03434</a></td><td> Circuito 0028 (003 - Colón) </td><td> 229 </td><td>5</td><td> 17.27</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/026/0373/040260373_08376.htm'>Mesa 08376</a></td><td> Circuito 0373 (026 - Unión) </td><td> 240 </td><td>11</td><td> 40.75</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/013/0179/040130179_05933.htm'>Mesa 05933</a></td><td> Circuito 0179 (013 - Río Cuarto) </td><td> 244 </td><td>1</td><td> 25.57</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/006/0089/040060089_04450.htm'>Mesa 04450</a></td><td> Circuito 0089 (006 - General San Martín) </td><td> 255 </td><td>1</td><td> 35.54</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/006/0090/040060090_04654.htm'>Mesa 04654</a></td><td> Circuito 0090 (006 - General San Martín) </td><td> 233 </td><td>5</td><td> 35.80</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/006/0090/040060090_04640.htm'>Mesa 04640</a></td><td> Circuito 0090 (006 - General San Martín) </td><td> 193 </td><td>2</td><td> 35.80</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/023/0340/040230340_08033.htm'>Mesa 08033</a></td><td> Circuito 0340 (023 - Tercero Arriba) </td><td> 209 </td><td>1</td><td> 12.33</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/005/0070/040050070_04306.htm'>Mesa 04306</a></td><td> Circuito 0070 (005 - General Roca) </td><td> 226 </td><td>2</td><td> 9.47</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/005/0070/040050070_04299.htm'>Mesa 04299</a></td><td> Circuito 0070 (005 - General Roca) </td><td> 227 </td><td>2</td><td> 9.47</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/020/0277/040200277_07146.htm'>Mesa 07146</a></td><td> Circuito 0277 (020 - San Justo) </td><td> 230 </td><td>1</td><td> 3.67</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/014/0222/040140222_06475.htm'>Mesa 06475</a></td><td> Circuito 0222 (014 - Río Primero) </td><td> 222 </td><td>1</td><td> 3.33</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/014/0222/040140222_06474.htm'>Mesa 06474</a></td><td> Circuito 0222 (014 - Río Primero) </td><td> 223 </td><td>1</td><td> 3.33</td></tr><tr><td><a href='http://www.resulta ...

# %% [markdown]
# ### Mesas no computadas

# %%
html = '<table class="table"><tr><th>Mesa</th><th>Circuito</th></tr>'
for mesa in Mesa.objects.filter(resultados__votos=0).distinct():
    if mesa.resultados.all().aggregate(p=Avg('votos'))['p'] != 0:
        # no computadas
        continue        
    html += f"<tr><td><a href='{mesa.absolute_url}'>Mesa {mesa.numero}</a></td><td> {mesa.circuito} </td></tr>"
html += '</table>'
    
display_html(HTML(html))
# Out:
# <table class="table"><tr><th>Mesa</th><th>Circuito</th></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0040/040030040_03903.htm'>Mesa 03903</a></td><td> Circuito 0040 (003 - Colón) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0040/040030040_03897.htm'>Mesa 03897</a></td><td> Circuito 0040 (003 - Colón) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0040A/040030040A03938.htm'>Mesa 03938</a></td><td> Circuito 0040A (003 - Colón) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0040/040030040_03872.htm'>Mesa 03872</a></td><td> Circuito 0040 (003 - Colón) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04714.htm'>Mesa 04714</a></td><td> Circuito 0095 (007 - Ischilin) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0227D/040150227D06496.htm'>Mesa 06496</a></td><td> Circuito 0227D (015 - Río Seco) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0041A/040030041A04043.htm'>Mesa 04043</a></td><td> Circuito 0041A (003 - Colón) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014Q/040010014Q03254.htm'>Mesa 03254</a></td><td> Circuito 0014Q (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014Q/040010014Q03253.htm'>Mesa 03253</a></td><td> Circuito 0014Q (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014/040010014_02910.htm'>Mesa 02910</a></td><td> Circuito 0014 (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014/040010014_02905.htm'>Mesa 02905</a></td><td> Circuito 0014 (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014/040010014_02901.htm'>Mesa 02901</a></td><td> Circuito 0014 (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014/040010014_02902.htm'>Mesa 02902</a></td><td> Circuito 0014 (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014B/040010014B02984.htm'>Mesa 02984</a></td><td> Circuito 0014B (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014B/040010014B02982.htm'>Mesa 02982</a></td><td> Circuito 0014B (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014L/040010014L03165.htm'>Mesa 03165</a></td><td> Circuito 0014L (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014L/040010014L03166.htm'>Mesa 03166</a></td><td> Circuito 0014L (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014L/040010014L03164.htm'>Mesa 03164</a></td><td> Circuito 0014L (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014L/040010014L03163.htm'>Mesa 03163</a></td><td> Circuito 0014L (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014L/040010014L03162.htm'>Mesa 03162</a></td><td> Circuito 0014L (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014L/040010014L03160.htm'>Mesa 03160</a></td><td> Circuito 0014L (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014L/040010014L03161.htm'>Mesa 03161</a></td><td> Circuito 0014L (001 - Capital) </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014O/040010014O03231.htm'>Mesa 03231</a></td><td> Circuito 0014O (001 - Capital) </td></tr><tr><td> ...

# %% [markdown]
# ### Mesas para los que  FCC sacó 0 votos

# %%
html = '<table class="table"><tr><th>Mesa</th><th>Circuito</th><th>Computados</th><th>Promedio UC/Circ</th></tr>'
for mesa in Mesa.objects.filter(resultados__votos=0, resultados__opcion__id__in=FCC).distinct():
    if mesa.resultados.all().aggregate(p=Avg('votos'))['p'] == 0:
        # ignorar no computadas
        continue
    
    promedio_circuito = VotoMesa.objects.filter(mesa__circuito=mesa.circuito, opcion__id__in=FCC).aggregate(p=Avg('votos'))['p']
    
    html += f"<tr><td><a href='{mesa.absolute_url}'>Mesa {mesa.numero}</a></td><td> {mesa.circuito} </td><td> {mesa.computados} </td><td> {promedio_circuito:.2f} </td></tr>"
html += '</table>'
    
display_html(HTML(html))
# Out:
# <table class="table"><tr><th>Mesa</th><th>Circuito</th><th>Computados</th><th>Promedio UC/Circ</th></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/020/0290/040200290_07304.htm'>Mesa 07304</a></td><td> Circuito 0290 (020 - San Justo) </td><td> 227 </td><td> 7.00 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0039/040030039_03861.htm'>Mesa 03861</a></td><td> Circuito 0039 (003 - Colón) </td><td> 30 </td><td> 0.00 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0228/040150228_06498.htm'>Mesa 06498</a></td><td> Circuito 0228 (015 - Río Seco) </td><td> 168 </td><td> 16.88 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04681.htm'>Mesa 04681</a></td><td> Circuito 0095 (007 - Ischilin) </td><td> 186 </td><td> 30.69 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0013H/040010013H02713.htm'>Mesa 02713</a></td><td> Circuito 0013H (001 - Capital) </td><td> 193 </td><td> 19.54 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0013H/040010013H02703.htm'>Mesa 02703</a></td><td> Circuito 0013H (001 - Capital) </td><td> 213 </td><td> 19.54 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0013I/040010013I02759.htm'>Mesa 02759</a></td><td> Circuito 0013I (001 - Capital) </td><td> 227 </td><td> 26.00 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0011G/040010011G01961.htm'>Mesa 01961</a></td><td> Circuito 0011G (001 - Capital) </td><td> 230 </td><td> 20.29 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0012F/040010012F02376.htm'>Mesa 02376</a></td><td> Circuito 0012F (001 - Capital) </td><td> 225 </td><td> 23.57 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0011A/040010011A01748.htm'>Mesa 01748</a></td><td> Circuito 0011A (001 - Capital) </td><td> 8 </td><td> 24.62 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0009C/040010009C01085.htm'>Mesa 01085</a></td><td> Circuito 0009C (001 - Capital) </td><td> 210 </td><td> 23.51 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/020/0312/040200312_07668.htm'>Mesa 07668</a></td><td> Circuito 0312 (020 - San Justo) </td><td> 12 </td><td> 0.00 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0006F/040010006F00656.htm'>Mesa 00656</a></td><td> Circuito 0006F (001 - Capital) </td><td> 219 </td><td> 18.17 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/020/0310/040200310_07584.htm'>Mesa 07584</a></td><td> Circuito 0310 (020 - San Justo) </td><td> 240 </td><td> 16.95 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/020/0310A/040200310A07626.htm'>Mesa 07626</a></td><td> Circuito 0310A (020 - San Justo) </td><td> 216 </td><td> 16.60 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/016/0242A/040160242A06689.htm'>Mesa 06689</a></td><td> Circuito 0242A (016 - Río Segundo) </td><td> 5 </td><td> 0.00 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/020/0291A/040200291A07324.htm'>Mesa 07324</a></td><td> Circuito 0291A (020 - San Justo) </td><td> 45 </td><td> 0.00 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/020/0296/040200296_07352.htm'>Mesa 07352</a></td><td> Circuito 0296 (020 - San Justo) </td><td> 181 </td><td> 4.57 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/026/0397A/040260397A08634.htm'>Mesa 08634</a></td><td> Circuito 0397A (026 - Unión) </td><td> 4 </td><td> 0.00 </td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/0 ...

# %% [markdown]
# ### Mesas para los que Cambiemos sacó 190% (o más) del promedio de su circuito

# %%
mesas = []
for circuito in Circuito.objects.all():
    promedio_circuito = VotoMesa.objects.filter(mesa__circuito=circuito, opcion__id__in=CAMBIEMOS).aggregate(p=Avg('votos'))['p']
    if not promedio_circuito:
        continue
    
    for mesa in Mesa.objects.filter(circuito=circuito, resultados__votos__gt=0, 
                                    resultados__votos__gte=promedio_circuito*1.9, 
                                    resultados__opcion__id__in=CAMBIEMOS):
        vot = mesa.resultados.filter(opcion__id__in=CAMBIEMOS).aggregate(p=Sum('votos'))['p']
        mesas.append((mesa, vot, promedio_circuito))

# %%
html = '<table class="table"><tr><th>Mesa</th><th>Circuito</th><th>Computados</th><th>Votos CAMBIEMOS</th><th>Promedio CAMBIEMOS/Circ</th></tr>'
for l in mesas:
    mesa, vot, promedio_circuito = l
    html += f"<tr><td><a href='{mesa.absolute_url}'>Mesa {mesa.numero}</a></td><td> {mesa.circuito} </td><td> {mesa.computados} </td><td>{vot}</td><td> {promedio_circuito:.2f}</td></tr>"
html += '</table>'
    
display_html(HTML(html))
# Out:
# <table class="table"><tr><th>Mesa</th><th>Circuito</th><th>Computados</th><th>Votos CAMBIEMOS</th><th>Promedio CAMBIEMOS/Circ</th></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0223/040150223_06478.htm'>Mesa 06478</a></td><td> Circuito 0223 (015 - Río Seco) </td><td> 117 </td><td>70</td><td> 31.33</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0225/040150225_06482.htm'>Mesa 06482</a></td><td> Circuito 0225 (015 - Río Seco) </td><td> 171 </td><td>47</td><td> 12.67</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0227B/040150227B06493.htm'>Mesa 06493</a></td><td> Circuito 0227B (015 - Río Seco) </td><td> 132 </td><td>56</td><td> 26.75</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0227D/040150227D06497.htm'>Mesa 06497</a></td><td> Circuito 0227D (015 - Río Seco) </td><td> 143 </td><td>78</td><td> 19.50</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0228/040150228_06505.htm'>Mesa 06505</a></td><td> Circuito 0228 (015 - Río Seco) </td><td> 208 </td><td>83</td><td> 37.38</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0228/040150228_06504.htm'>Mesa 06504</a></td><td> Circuito 0228 (015 - Río Seco) </td><td> 188 </td><td>96</td><td> 37.38</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0228/040150228_06500.htm'>Mesa 06500</a></td><td> Circuito 0228 (015 - Río Seco) </td><td> 189 </td><td>87</td><td> 37.38</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0229/040150229_06514.htm'>Mesa 06514</a></td><td> Circuito 0229 (015 - Río Seco) </td><td> 212 </td><td>95</td><td> 41.20</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0229/040150229_06509.htm'>Mesa 06509</a></td><td> Circuito 0229 (015 - Río Seco) </td><td> 234 </td><td>104</td><td> 41.20</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/015/0229/040150229_06508.htm'>Mesa 06508</a></td><td> Circuito 0229 (015 - Río Seco) </td><td> 234 </td><td>112</td><td> 41.20</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0091A/040070091A04660.htm'>Mesa 04660</a></td><td> Circuito 0091A (007 - Ischilin) </td><td> 11 </td><td>4</td><td> 2.00</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0093/040070093_04665.htm'>Mesa 04665</a></td><td> Circuito 0093 (007 - Ischilin) </td><td> 139 </td><td>35</td><td> 14.25</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04716.htm'>Mesa 04716</a></td><td> Circuito 0095 (007 - Ischilin) </td><td> 238 </td><td>104</td><td> 40.48</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04711.htm'>Mesa 04711</a></td><td> Circuito 0095 (007 - Ischilin) </td><td> 231 </td><td>106</td><td> 40.48</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04698.htm'>Mesa 04698</a></td><td> Circuito 0095 (007 - Ischilin) </td><td> 243 </td><td>95</td><td> 40.48</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04687.htm'>Mesa 04687</a></td><td> Circuito 0095 (007 - Ischilin) </td><td> 216 </td><td>97</td><td> 40.48</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04684.htm'>Mesa 04684</a></td><td> Circuito 0095 (007 - Ischilin) </td><td> 258 </td><td>122</td><td> 40.48</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04682.htm'>Mesa 04682</a></td><td> Circuito 0095 (007 - Ischilin) </td><td> 242 </td><td>120</td><td> 40.48</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/cont ...

# %% [markdown]
# ### Mesas con muchos votos nulos

# %%
html = '<table class="table"><tr><th>Mesa</th><th>Circuito</th><th>Computados</th><th>Votos Nulos</th></tr>'
for mesa in Mesa.objects.filter(resultados__opcion__id=1, resultados__votos__gte=18).distinct():
    vot = mesa.resultados.get(opcion__id=1).votos
    html += f"<tr><td><a href='{mesa.absolute_url}'>Mesa {mesa.numero}</a></td><td> {mesa.circuito} </td><td> {mesa.computados} </td><td>{vot}</td></tr>"
html += '</table>'
    
display_html(HTML(html))
# Out:
# <table class="table"><tr><th>Mesa</th><th>Circuito</th><th>Computados</th><th>Votos Nulos</th></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0040/040030040_03869.htm'>Mesa 03869</a></td><td> Circuito 0040 (003 - Colón) </td><td> 257 </td><td>19</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/003/0040/040030040_03866.htm'>Mesa 03866</a></td><td> Circuito 0040 (003 - Colón) </td><td> 246 </td><td>19</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/007/0095/040070095_04685.htm'>Mesa 04685</a></td><td> Circuito 0095 (007 - Ischilin) </td><td> 239 </td><td>25</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014A/040010014A02948.htm'>Mesa 02948</a></td><td> Circuito 0014A (001 - Capital) </td><td> 240 </td><td>18</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014H/040010014H03099.htm'>Mesa 03099</a></td><td> Circuito 0014H (001 - Capital) </td><td> 247 </td><td>19</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0014N/040010014N03209.htm'>Mesa 03209</a></td><td> Circuito 0014N (001 - Capital) </td><td> 239 </td><td>21</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0013D/040010013D02615.htm'>Mesa 02615</a></td><td> Circuito 0013D (001 - Capital) </td><td> 253 </td><td>22</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0013G/040010013G02683.htm'>Mesa 02683</a></td><td> Circuito 0013G (001 - Capital) </td><td> 237 </td><td>18</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0013H/040010013H02730.htm'>Mesa 02730</a></td><td> Circuito 0013H (001 - Capital) </td><td> 171 </td><td>18</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0013G/040010013G02646.htm'>Mesa 02646</a></td><td> Circuito 0013G (001 - Capital) </td><td> 259 </td><td>21</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0011K/040010011K02116.htm'>Mesa 02116</a></td><td> Circuito 0011K (001 - Capital) </td><td> 234 </td><td>20</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0011G/040010011G01947.htm'>Mesa 01947</a></td><td> Circuito 0011G (001 - Capital) </td><td> 221 </td><td>21</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0011I/040010011I02033.htm'>Mesa 02033</a></td><td> Circuito 0011I (001 - Capital) </td><td> 230 </td><td>21</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0012D/040010012D02340.htm'>Mesa 02340</a></td><td> Circuito 0012D (001 - Capital) </td><td> 246 </td><td>19</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0012D/040010012D02336.htm'>Mesa 02336</a></td><td> Circuito 0012D (001 - Capital) </td><td> 232 </td><td>22</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0012D/040010012D02312.htm'>Mesa 02312</a></td><td> Circuito 0012D (001 - Capital) </td><td> 232 </td><td>24</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0012C/040010012C02254.htm'>Mesa 02254</a></td><td> Circuito 0012C (001 - Capital) </td><td> 233 </td><td>18</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0012G/040010012G02424.htm'>Mesa 02424</a></td><td> Circuito 0012G (001 - Capital) </td><td> 248 </td><td>21</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0013/040010013_02500.htm'>Mesa 02500</a></td><td> Circuito 0013 (001 - Capital) </td><td> 236 </td><td>19</td></tr><tr><td><a href='http://www.resultados.gob.ar/99/resu/content/telegramas/04/001/0010E/040010010E01361.htm'>Mesa 01361</a></td><td> Circuito 0010E (001 - Capital) </td><t ...
